# %%
# !nvidia-smi
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 896.9/896.9 kB 21.5 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import os
from IPython.display import display, Image , clear_output
clear_output()
# !yolo checks
# Out:
# Ultralytics 8.3.39 🚀 Python-3.10.12 torch-2.5.1+cu121 CPU (Intel Xeon 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 32.6/107.7 GB disk)
#
# OS                  Linux-6.1.85+-x86_64-with-glibc2.35
# Environment         Colab
# Python              3.10.12
# Install             pip
# RAM                 12.67 GB
# Disk                32.6/107.7 GB
# CPU                 Intel Xeon 2.20GHz
# CPU count           2
# GPU                 None
# GPU count           None
# CUDA                None
#
# numpy               ✅ 1.26.4>=1.23.0
# numpy               ✅ 1.26.4<2.0.0; sys_platform == "darwin"
# matplotlib          ✅ 3.8.0>=3.3.0
# opencv-python       ✅ 4.10.0.84>=4.6.0
# pillow              ✅ 11.0.0>=7.1.2
# pyyaml              ✅ 6.0.2>=5.3.1
# requests            ✅ 2.32.3>=2.23.0
# scipy               ✅ 1.13.1>=1.4.1
# torch               ✅ 2.5.1+cu121>=1.8.0
# torch               ✅ 2.5.1+cu121!=2.4.0,>=1.8.0; sys_platform == "win32"
# torchvision         ✅ 0.20.1+cu121>=0.9.0
# ...

# %%
# !pip install roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.9/80.9 kB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 2.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="weybJezBYVCQ2eiqFtb3")
project = rf.workspace("sign-language-detection-dmww4").project("sign-language-detection-1w7ye")
version = project.version(3)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to sign-language-detection-3 in yolov8:: 100%|██████████| 72/72 [00:00<00:00, 1303.79it/s]

# %%
# !yolo task=detect mode=train model=/content/yolov8s.pt  data = /content/sign-language-detection-3/data.yaml epochs=30 imgsz=640
# Out:
# ...
# 100% 21.5M/21.5M [00:00<00:00, 208MB/s]
# Ultralytics 8.3.39 🚀 Python-3.10.12 torch-2.5.1+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
from google.colab import drive
import os

# Mount Google Drive
drive.mount('/content/drive')

# Define the source and destination paths
source_path = '/content/runs/detect/train/weights/best.pt'
destination_path = 'C:\\Users\\ALOK\\OneDrive\\Desktop\\sign language detection'  # Choose your desired destination on Google Drive

# Copy the file to Google Drive
# !cp "{source_path}" "{destination_path}"

print(f"File copied to: C:\\Users\\ALOK\\OneDrive\\Desktop\\sign language detection")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# File copied to: C:\Users\ALOK\OneDrive\Desktop\sign language detection

# %%
from google.colab import files
import os
import zipfile

# Define the path to the best.pt file
best_pt_path = '/content/runs/detect/train/weights/best.pt'

# Create a zip file containing best.pt
zip_file_path = 'best_model.zip'
with zipfile.ZipFile(zip_file_path, 'w') as zipf:
    zipf.write(best_pt_path, os.path.basename(best_pt_path))

# Download the zip file
files.download(zip_file_path)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # New Section
